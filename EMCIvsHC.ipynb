# %%
import pandas as pd

df1= pd.read_csv('EMCI.csv')
df2= pd.read_excel('HC.xlsx')
print(df1.head())
print(df2.head())
# Out:
#       PID  Patient ID      Sex      Age  Report Date  Scale factor      SNR  \
# 0  2010.0  job1701869  UNKNOWN  UNKNOWN  12-Jun-2024       0.65914  21.8233
# 1  2010.0  job1701872  UNKNOWN  UNKNOWN  12-Jun-2024       0.62870  16.2326
# 2  2010.0  job1701874  UNKNOWN  UNKNOWN  12-Jun-2024       0.64257  22.4654
# 3  2010.0  job1701875  UNKNOWN  UNKNOWN  12-Jun-2024       0.64244  23.4545
# 4  2010.0  job1701879  UNKNOWN  UNKNOWN  12-Jun-2024       0.63612  21.6140
#
#       mSNR       QC  Tissue WM cm3  ...  Amygdala Left cm3  Amygdala Left %  \
# 0  22.2069  0.95031       386.3687  ...            0.92280             0.08
# 1  16.0839  0.94907       366.9233  ...            0.89527             0.07
# 2  22.9172  0.95168       371.8851  ...            0.86747             0.07
# 3  23.9314  0.95228       366.1105  ...            0.88143             0.07
# 4  22.1309  0.95335       366.9811  ...            0.87594             0.07
#
#    Amygdala Asymmetry  Accumbens Total cm3  Accumbens Total %  \
# 0             2.74740              0.65848               0.05
# 1             5.79610              0.65259               0.05
# 2             5.96480              0.64964               0.05
# 3             4.62800              0.61931               0.05
# 4             0.79566              0.63231               0.05
#
#    Accumbens Right cm3  Accumbens Right %  Accumbens Left cm3  \
# 0              0.32825               0.03             0.33023
# 1              0.33195               0.03             0.32064
# 2              0.33157               0.03             0.31807
# 3              0.30966               0.03             0.30966
# 4              0.30089               0.03             0.33142
#
#    Accumbens Left %  Accumbens Asymmetry
# 0              0.03              -0.6006
# 1              0.03               3.4682
# 2              0.03               4.1543
# 3              0.03               0.0000
# 4              0.03              -9.6579
#
# [5 rows x 115 columns]
#    Patient ID White Matter(cm3/%) Grey Matter(cm3/%)  \
# 0      286855     579.08 (37.09%)    725.93 (46.49%)
# 1      286856     662.72 (44.17%)    684.87 (45.65%)
# 2      286857     612.38 (40.27%)    756.10 (49.72%)
# 3      286858     643.65 (38.88%)    760.99 (45.97%)
# 4      286859     504.46 (36.74%)    723.19 (52.68%)
#
#   Cerebro Spinal Fluid (cm3/%) Brain(WM+GM) (cm3/%)  \
# 0              256.47 (16.42%)     1305.02 (83.58%)
# 1              152.77 (10.18%)     1347.60 (89.82%)
# 2              152.38 (10.02%)     1368.48 (89.98%)
# 3              250.66 (15.14%)     1404.65 (84.86%)
# 4              145.25 (10.58%)     1227.65 (89.42%)
#
#   Intracranial Cavity(IC) (cm3/%)
# 0               1561.49 (100.00%)
# 1               1500.37 (100.00%)
# 2               1520.86 (100.00%)
# 3               1655.30 (100.00%)
# 4               1372.90 (100.00%)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Columns: 115 entries, PID to Accumbens Asymmetry
# dtypes: float64(110), int64(1), object(4)
# memory usage: 95.4+ KB

# %%
df2['Tissue WM %'] = df2['White Matter(cm3/%)'].str.extract('(\d+(?:\.\d+)?)%').astype(float)
df2['Tissue GM %'] = df2['Grey Matter(cm3/%)'].str.extract('(\d+(?:\.\d+)?)%').astype(float)
df2['Tissue CSF %'] = df2['Cerebro Spinal Fluid (cm3/%)'].str.extract('(\d+(?:\.\d+)?)%').astype(float)

# %%
df2['Label']='HC'
df1['Label']='EMCI'

# %%
df2.head()
# Out:
#    Patient ID White Matter(cm3/%) Grey Matter(cm3/%)  \
# 0      286855     579.08 (37.09%)    725.93 (46.49%)
# 1      286856     662.72 (44.17%)    684.87 (45.65%)
# 2      286857     612.38 (40.27%)    756.10 (49.72%)
# 3      286858     643.65 (38.88%)    760.99 (45.97%)
# 4      286859     504.46 (36.74%)    723.19 (52.68%)
#
#   Cerebro Spinal Fluid (cm3/%) Brain(WM+GM) (cm3/%)  \
# 0              256.47 (16.42%)     1305.02 (83.58%)
# 1              152.77 (10.18%)     1347.60 (89.82%)
# 2              152.38 (10.02%)     1368.48 (89.98%)
# 3              250.66 (15.14%)     1404.65 (84.86%)
# 4              145.25 (10.58%)     1227.65 (89.42%)
#
#   Intracranial Cavity(IC) (cm3/%)  Tissue WM %  Tissue GM %  Tissue CSF %  \
# 0               1561.49 (100.00%)        37.09        46.49         16.42
# 1               1500.37 (100.00%)        44.17        45.65         10.18
# 2               1520.86 (100.00%)        40.27        49.72         10.02
# 3               1655.30 (100.00%)        38.88        45.97         15.14
# 4               1372.90 (100.00%)        36.74        52.68         10.58
#
#   Label
# 0    HC
# 1    HC
# 2    HC
# 3    HC
# 4    HC

# %%
df1.head()
# Out:
#       PID  Patient ID      Sex      Age  Report Date  Scale factor      SNR  \
# 0  2010.0  job1701869  UNKNOWN  UNKNOWN  12-Jun-2024       0.65914  21.8233
# 1  2010.0  job1701872  UNKNOWN  UNKNOWN  12-Jun-2024       0.62870  16.2326
# 2  2010.0  job1701874  UNKNOWN  UNKNOWN  12-Jun-2024       0.64257  22.4654
# 3  2010.0  job1701875  UNKNOWN  UNKNOWN  12-Jun-2024       0.64244  23.4545
# 4  2010.0  job1701879  UNKNOWN  UNKNOWN  12-Jun-2024       0.63612  21.6140
#
#       mSNR       QC  Tissue WM cm3  ...  Amygdala Left %  Amygdala Asymmetry  \
# 0  22.2069  0.95031       386.3687  ...             0.08             2.74740
# 1  16.0839  0.94907       366.9233  ...             0.07             5.79610
# 2  22.9172  0.95168       371.8851  ...             0.07             5.96480
# 3  23.9314  0.95228       366.1105  ...             0.07             4.62800
# 4  22.1309  0.95335       366.9811  ...             0.07             0.79566
#
#    Accumbens Total cm3  Accumbens Total %  Accumbens Right cm3  \
# 0              0.65848               0.05              0.32825
# 1              0.65259               0.05              0.33195
# 2              0.64964               0.05              0.33157
# 3              0.61931               0.05              0.30966
# 4              0.63231               0.05              0.30089
#
#    Accumbens Right %  Accumbens Left cm3  Accumbens Left %  \
# 0               0.03             0.33023              0.03
# 1               0.03             0.32064              0.03
# 2               0.03             0.31807              0.03
# 3               0.03             0.30966              0.03
# 4               0.03             0.33142              0.03
#
#    Accumbens Asymmetry  Label
# 0              -0.6006   EMCI
# 1               3.4682   EMCI
# 2               4.1543   EMCI
# 3               0.0000   EMCI
# 4              -9.6579   EMCI
#
# [5 rows x 116 columns]

# %%
df= pd.concat([df1,df2])
df.head(-5)
# Out:
#        PID  Patient ID      Sex      Age  Report Date  Scale factor      SNR  \
# 0   2010.0  job1701869  UNKNOWN  UNKNOWN  12-Jun-2024       0.65914  21.8233
# 1   2010.0  job1701872  UNKNOWN  UNKNOWN  12-Jun-2024       0.62870  16.2326
# 2   2010.0  job1701874  UNKNOWN  UNKNOWN  12-Jun-2024       0.64257  22.4654
# 3   2010.0  job1701875  UNKNOWN  UNKNOWN  12-Jun-2024       0.64244  23.4545
# 4   2010.0  job1701879  UNKNOWN  UNKNOWN  12-Jun-2024       0.63612  21.6140
# ..     ...         ...      ...      ...          ...           ...      ...
# 50     NaN      286908      NaN      NaN          NaN           NaN      NaN
# 51     NaN      286909      NaN      NaN          NaN           NaN      NaN
# 52     NaN      286910      NaN      NaN          NaN           NaN      NaN
# 53     NaN      286911      NaN      NaN          NaN           NaN      NaN
# 54     NaN      286912      NaN      NaN          NaN           NaN      NaN
#
#        mSNR       QC  Tissue WM cm3  ...  Accumbens Right %  \
# 0   22.2069  0.95031       386.3687  ...               0.03
# 1   16.0839  0.94907       366.9233  ...               0.03
# 2   22.9172  0.95168       371.8851  ...               0.03
# 3   23.9314  0.95228       366.1105  ...               0.03
# 4   22.1309  0.95335       366.9811  ...               0.03
# ..      ...      ...            ...  ...                ...
# 50      NaN      NaN            NaN  ...                NaN
# 51      NaN      NaN            NaN  ...                NaN
# 52      NaN      NaN            NaN  ...                NaN
# 53      NaN      NaN            NaN  ...                NaN
# 54      NaN      NaN            NaN  ...                NaN
#
#     Accumbens Left cm3  Accumbens Left %  Accumbens Asymmetry  Label  \
# 0              0.33023              0.03              -0.6006   EMCI
# 1              0.32064              0.03               3.4682   EMCI
# 2              0.31807              0.03               4.1543   EMCI
# 3              0.30966              0.03               0.0000   EMCI
# 4              0.33142              0.03              -9.6579   EMCI
# ..                 ...               ...                  ...    ...
# 50                 NaN               NaN                  NaN     HC
# 51                 NaN               NaN                  NaN     HC
# 52                 NaN               NaN                  NaN     HC
# 53                 NaN               NaN                  NaN     HC
# 54                 NaN               NaN                  NaN     HC
#
#     White Matter(cm3/%)  Grey Matter(cm3/%)  Cerebro Spinal Fluid (cm3/%)  \
# 0                   NaN                 NaN                           NaN
# 1                   NaN                 NaN                           NaN
# 2                   NaN                 NaN                           NaN
# 3                   NaN                 NaN                           NaN
# 4                   NaN                 NaN                           NaN
# ..                  ...                 ...                           ...
# 50      472.04 (40.17%)     606.70 (51.63%)                96.26 ( 8.19%)
# 51      491.78 (32.99%)     691.40 (46.38%)               307.71 (20.64%)
# 52      466.93 (37.37%)     588.45 (47.10%)               194.02 (15.53%)
# 53      484.20 (37.24%)     699.08 (53.76%)               117.09 ( 9.00%)
# 54      417.39 (36.64%)     606.20 (53.21%)               115.62 (10.15%)
#
#     Brain(WM+GM) (cm3/%)  Intracranial Cavity(IC) (cm3/%)
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    NaN                              NaN
# 3                    NaN                              NaN
# 4                    NaN                              NaN
# ..                   ...                              ...
# 50      1078.74 (91.81%)                1175.00 (100.00%)
# 51      1183.18 (79.36%)                1490.89 (100.00%)
# 52      1055.39 (84.47%)                1249.41 (100.00%)
# 53      1183.27 (91.00%)                1300.36 (100.00%)
# 54      1023.59 (89.85%)                1139.21 (100.00%)
#
# [161 rows x 121 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 166 entries, 0 to 59
# Columns: 121 entries, PID to Intracranial Cavity(IC) (cm3/%)
# dtypes: float64(111), object(10)
# memory usage: 158.2+ KB

# %%
df.isna().sum()
# Out:
# PID                                118
# Patient ID                           0
# Sex                                 60
# Age                                 60
# Report Date                         60
#                                   ...
# White Matter(cm3/%)                106
# Grey Matter(cm3/%)                 106
# Cerebro Spinal Fluid (cm3/%)       106
# Brain(WM+GM) (cm3/%)               106
# Intracranial Cavity(IC) (cm3/%)    106
# Length: 121, dtype: int64

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import numpy as np

# Select features and label
X = df[['Tissue GM %','Tissue WM %','Tissue CSF %']]
y = df['Label']
print(X.columns.tolist())
# Encode the labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Define hyperparameter tuning space
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.5, 1],
    'n_estimators': [40, 42, 45],
    'alpha': [0, 0.1, 0.5],
    'lambda': [0, 0.1, 0.5]
}

# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=62)

# Initialize XGBoost model
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss')

# Perform GridSearchCV
grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, scoring='f1', n_jobs=-1)
grid_search.fit(X, y_encoded)

# Print best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# Get the best model
best_model = grid_search.best_estimator_

# Metrics storage
accuracies = []
precisions = []
recalls = []
f1_scores = []

# Perform K-Fold cross-validation with the best model
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y_encoded[train_index], y_encoded[test_index]

    # Train the model
    best_model.fit(X_train, y_train)

    # Make predictions
    preds = best_model.predict(X_test)
    predicted_labels = preds

    # Evaluate the model
    accuracy = accuracy_score(y_test, predicted_labels)
    precision = precision_score(y_test, predicted_labels)
    recall = recall_score(y_test, predicted_labels)
    f1 = f1_score(y_test, predicted_labels)

    # Store metrics
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

# Calculate average metrics
mean_accuracy = np.mean(accuracies)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_f1 = np.mean(f1_scores)

# Print metrics
print(f"Mean Accuracy: {mean_accuracy * 100:.2f}%")
print(f"Mean Precision: {mean_precision * 100:.2f}%")
print(f"Mean Recall: {mean_recall * 100:.2f}%")
print(f"Mean F1 score: {mean_f1 * 100:.2f}%")
# Out:
# ['Tissue GM %', 'Tissue WM %', 'Tissue CSF %']
# Best Parameters: {'alpha': 0, 'lambda': 0, 'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 40}
# Best Score: 0.9530721966205837
# Mean Accuracy: 96.36%
# Mean Precision: 95.67%
# Mean Recall: 95.52%
# Mean F1 score: 95.31%
